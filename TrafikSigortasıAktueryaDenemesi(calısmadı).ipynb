# %%
sehirOranları={"adana":0.1,
               "ankaraOrani":0.6,
               "antalya":0.70,
               "aydın":0.8,
               "balikesir":1.4,
               "istanbulOranı":3.4,
               "bursaOranı":1.6
              }

# %%
aracTipOranı={"otomobil":0.5,
              "motorsiletOranı":0.2,
              "KamyonOrani":0.7
}

# %%
aracTuruOrannı={"ozel":0.5,
                "Tuzel":0.3
               }

# %%
basamakOranı={"hasarBasamagı0":1,
              "hasarBasamagı1":0.9,
              "hasarBasamagı2":0.8,
              "hasarBasamagı3":0.7,
              "hasarBasamagı4":0.6,
              "hasarBasamagı5":0.5,
              "hasarBasamagı6":0.4,
              "hasarBasamagı7":0.3,
              "hasarBasamagı8":0.2,
              "hasarBasamagı9":0.1
             }

# %%
sonuc=ankaraOrani*motorsiletOranı
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sonuc=ankaraOrani*motorsiletOranı
#
# NameError: name 'ankaraOrani' is not defined

# %%
sonuc=adana*KamyonOrani*ozel*hasarBasamagı5
print("Çarpım sonucu",sonuc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sonuc=adana*KamyonOrani*ozel*hasarBasamagı5
#       2 print("Çarpım sonucu",sonuc)
#
# NameError: name 'adana' is not defined

# %%
def hesapla(sehirOranları,aracTipOranı,islem):
     if islem=="*":
        return(str(s)+" * "+str(a)+" = "+str(s*a))

while True:
    try:
        s=int(input("ilk sayıyı giriniz:"))
        a=int(input("ikinci sayıyı giriniz:"))
        islem=input("işleminizi seçiniz: *")
        print(hesapla(a,b,islem))
    except:
        print("Lütfen sayıları düzgün griniz")
# Out:
# ilk sayıyı giriniz: adana
# Lütfen sayıları düzgün griniz
# ilk sayıyı giriniz: 1
# ikinci sayıyı giriniz: 5
# işleminizi seçiniz: * *
# Lütfen sayıları düzgün griniz
# ilk sayıyı giriniz: 1
# ikinci sayıyı giriniz: 8
# işleminizi seçiniz: * *
# Lütfen sayıları düzgün griniz
# Lütfen sayıları düzgün griniz
